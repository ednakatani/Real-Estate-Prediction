# %% [markdown]
# <h1> Model Training - Multilayer Perceptron</h1>

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("data/usa_real_estate.csv", sep=",", encoding="utf-8")

# %%
df.head()
# Out:
#      status     price  bed  bath  acre_lot  \
# 0  for_sale  105000.0  3.0   2.0      0.12
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# ...

# %%
# dropping columns
df.drop(['street', 'full_address', 'sold_date', 'state', 'city', 'status'], axis=1, inplace=True)

# %%
# Dropping null collumns
df = df[df['bed'].notna()]
df = df[df['price'].notna()]
df = df[df['bath'].notna()]
df = df[df['acre_lot'].notna()]
df = df[df['zip_code'].notna()]
df = df[df['house_size'].notna()]

# %%
df = df.sample(frac=0.5,random_state=200)

# %%
x = df.drop("price", axis=1)
y = df["price"]

# %%
y_credit =y.to_numpy()

x_credit = x.to_numpy()

# %%
from sklearn.model_selection import train_test_split
x_credit_treinamento, x_credit_teste, y_credit_treinamento, y_credit_teste = train_test_split(x_credit, y_credit, test_size = 0.80, random_state = 0)

# %%
df = 0
x = 0
y = 0

# %%
rede_neural_credit = MLPClassifier(random_state=10, max_iter=1500, early_stopping=True, validation_fraction=0.2)
rede_neural_credit.fit(x_credit_treinamento, y_credit_treinamento)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7896\1562559346.py in <module>
#       1 rede_neural_credit = MLPClassifier(random_state=10, max_iter=1500, early_stopping=True, validation_fraction=0.2)
# ----> 2 rede_neural_credit.fit(x_credit_treinamento, y_credit_treinamento)
#
# c:\Users\dudun\AppData\Local\Programs\Python\Python37-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#     671         self : returns a trained MLP model.
#     672         """
# --> 673         return self._fit(X, y, incremental=False)
#     674
#     675     @property
#
# c:\Users\dudun\AppData\Local\Programs\Python\Python37-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     362                       (not self.warm_start and not incremental))
#     363
# ...

# %%
previsoes = rede_neural_credit.predict(x_credit_teste)
previsoes
# Out:
# array([ 650000., 2650000., 2650000., ...,  650000., 2650000., 2650000.])

# %%
y_credit_teste
# Out:
# array([ 520000., 2349162., 4600000., ...,  562352.,  950000.,  439990.])

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_score(y_credit_teste, previsoes)
# Out:
# 0.01064516129032258

# %%
print(classification_report(y_credit_teste, previsoes))
# Out:
#               precision    recall  f1-score   support
#
#      18000.0       0.00      0.00      0.00         1
#     119900.0       0.00      0.00      0.00         1
#     120000.0       0.00      0.00      0.00         1
#     125000.0       0.00      0.00      0.00         2
#     128000.0       0.00      0.00      0.00         1
#     130000.0       0.00      0.00      0.00         6
#     133000.0       0.00      0.00      0.00         1
#     134000.0       0.00      0.00      0.00         2
#     134700.0       0.00      0.00      0.00         1
#     135000.0       0.00      0.00      0.00         5
#     138000.0       0.00      0.00      0.00         1
#     139000.0       0.00      0.00      0.00         3
#     139990.0       0.00      0.00      0.00         1
#     140000.0       0.00      0.00      0.00         8
#     145000.0       0.00      0.00      0.00        11
#     148000.0       0.00      0.00      0.00         1
# ...
